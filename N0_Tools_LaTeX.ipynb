# %% [markdown]
# # Tools of Game Theory
#
# Every notebook begins with some initilization code. Don't edit it in any way. <span style="color:red;"><b>Just run it</b></span>.

# %%
## Do not change this cell, only execute it.

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import numpy as np
import scipy as sp
from scipy.optimize import linprog

# %% [markdown]
# ## $\LaTeX$
#
# The markdown cells in our UNG Datahub notebooks utilize the **LaTeX** equation editor which, in modern times, often is called **dollar sign mathematics (DSM)**.
#
# ### Task 1
#
# Create the following polynomial in DSM:
#
# y^2 - 3x +1 = 0

# %% [markdown]
# ### Task 2
#
# Create a vector $\vec r \in \mathbb{R}^3$ with compenents $2, -1$ and $4$.

# %% [markdown]
# ## Task 3
#
# Create a game matrix with top row of $0, -1, 4$ and a bottom row of $2, 1, 2$.

# %% [markdown]
# ### Task 3b
#
# Add player subtitles to the game above.

# %% [markdown]
# ### Task 4
#
# Use the `align` environment to gather the equation with each equation aligned by its equal sign:
#
# - $v_r = 2$
# - $v_c = -2$
# - $\vec r = (0.3, 0.3, 0.4)$
# - $\vec c = (0.3, 0.5, 0.2)$
