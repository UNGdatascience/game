# %% [markdown]
# # Tools of Game Theory
#
# Every notebook begins with some initilization code. Don't edit it in any way. <span style="color:red;"><b>Just run it</b></span>.

# %%
## Do not change this cell, only execute it.

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import numpy as np
import scipy as sp
from scipy.optimize import linprog

# %% [markdown]
# ## Graphics for Game Theory
#
# Let's begin with creating the graphics window and the $xy$-coordinate axes.
#
# ### Task 1
#
# Create a graphing window with the $xy$-coordinate axes.

# %% [markdown]
# ### Task 2
#
# In the graphics window you created above, add:
#
# - A vertical line through $x=3$.
# - A horizontal line through $y=1$.
#
# Can you make one line <span style="color:red"><b>red</b></span> and one line <span style="color:blue"><b>blue</b></span>? Can you make the vertical line show as dashes?

# %% [markdown]
# ### Task 3
#
# Create a new graphics window and axes with lines through the following points:
#
# - Line A through points $(1,3)$ and $(4,1)$.
# - Line B through points $(0,1)$ and $(5,4)$.

# %% [markdown]
# ### Task 4
#
# Create a new graphics window and axes with a polygon with the following points as its vertices.
#
# - $(1,1)$
# - $(1,4)$
# - $(3,5)$
# - $(4,2)$
# - $(2,0)$
