# %% [markdown]
# # Module Z1: Introduction to Game Theory
#
# You will need to watch the video and make sure to understand the following terms. Please explain each one in your own words in the cells provided.
#
# 1. Players
#
# In game theory, what is meant by the term **player**?

# %% [markdown]
# 2. Rational Play Principle
#
# Please state both components of the **rational play principle**.

# %% [markdown]
# 3. Strategy
#
# What do we mean in game theory when we refer to a player's strategy?

# %% [markdown]
# 4. Information
#
# In game theory, we describe two different game environments, one in which the players know everything about the game (except the opponent's choice of strategy), and one in which not everything is known. What are the terms for these games?

# %% [markdown]
# 5. Solution
#
# What do we mean when we say we have found a **solution** to a game?
